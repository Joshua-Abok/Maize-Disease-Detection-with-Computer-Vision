# %%
# visualize the image
import matplotlib.pyplot as plt
from PIL import Image

# %%
#Load the image using PIL 
image_path = "images/R.519f6879dec040303782b14014d91e78?rik=RDNQKnQ%2bNLITfw&riu=http%3a%2f%2fwww.infonet-biovision.org%2fsites%2fdefault%2ffiles%2fplant_health%2fpestsdiseasesweeds%2f1881_0.jpeg&ehk=GuWd9dI0RZxhQdOOh5fVc%2b5Kqgug3lEycHCAV1%2bcplM%3d&risl=&pid=ImgRaw&r=0"
img = Image.open(image_path)

# Display the image using Matplotlib
plt.imshow(img)
plt.axis('off')  #Hide the axis
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-b11993dcff67> in <module>
#       1 #Load the image using PIL
#       2 image_path = "images/R.519f6879dec040303782b14014d91e78?rik=RDNQKnQ%2bNLITfw&riu=http%3a%2f%2fwww.infonet-biovision.org%2fsites%2fdefault%2ffiles%2fplant_health%2fpestsdiseasesweeds%2f1881_0.jpeg&ehk=GuWd9dI0RZxhQdOOh5fVc%2b5Kqgug3lEycHCAV1%2bcplM%3d&risl=&pid=ImgRaw&r=0"
# ----> 3 img = Image.open(image_path)
#       4
#       5 # Display the image using Matplotlib
#
# ~\AppData\Roaming\Python\Python36\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# OSError: [Errno 22] Invalid argument: 'images/R.519f6879dec040303782b14014d91e78?rik=RDNQKnQ%2bNLITfw&riu=http%3a%2f%2fwww.infonet-biovision.org%2fsites%2fdefault%2ffiles%2fplant_health%2fpestsdiseasesweeds%2f1881_0.jpeg&ehk=GuWd9dI0RZxhQdOOh5fVc%2b5Kqgug3lEycHCAV1%2bcplM%3d&risl=&pid=ImgRaw&r=0'

# %%
plt.plot([10,20, 30, 40, 100], [0.001996755599975586, 0.0038220882415771484, 0.006999492645263672, 0.015996932983398438, 0.03540778160095215])
plt.show()

# %%
plt.plot([2,5, 8, 10, 12], [0.0, 0.000991, 0.001000, 0.001009, 0.000999])
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
